# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/stock.csv.csv')
df
# Out:
#             Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0     2018-10-08  208.00  222.25  ...  215.15               4642146         10062.83
# 1     2018-10-05  217.00  218.60  ...  209.20               3519515          7407.06
# 2     2018-10-04  223.50  227.80  ...  218.20               1728786          3815.79
# 3     2018-10-03  230.00  237.50  ...  227.60               1708590          3960.27
# 4     2018-10-01  234.55  234.60  ...  230.90               1534749          3486.05
# ...          ...     ...     ...  ...     ...                   ...              ...
# 1230  2013-10-14  160.85  161.45  ...  159.45               1281419          2039.09
# 1231  2013-10-11  161.15  163.45  ...  160.05               1880046          3030.76
# 1232  2013-10-10  156.00  160.80  ...  160.15               3124853          4978.80
# 1233  2013-10-09  155.70  158.20  ...  155.55               2049580          3204.49
# 1234  2013-10-08  157.00  157.80  ...  155.80               1720413          2688.94
#
# [1235 rows x 8 columns]

# %%
df.head()
# Out:
#          Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-10-08  208.00  222.25  ...  215.15               4642146         10062.83
# 1  2018-10-05  217.00  218.60  ...  209.20               3519515          7407.06
# 2  2018-10-04  223.50  227.80  ...  218.20               1728786          3815.79
# 3  2018-10-03  230.00  237.50  ...  227.60               1708590          3960.27
# 4  2018-10-01  234.55  234.60  ...  230.90               1534749          3486.05
#
# [5 rows x 8 columns]

# %%
df.tail()
# Out:
#             Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 1230  2013-10-14  160.85  161.45  ...  159.45               1281419          2039.09
# 1231  2013-10-11  161.15  163.45  ...  160.05               1880046          3030.76
# 1232  2013-10-10  156.00  160.80  ...  160.15               3124853          4978.80
# 1233  2013-10-09  155.70  158.20  ...  155.55               2049580          3204.49
# 1234  2013-10-08  157.00  157.80  ...  155.80               1720413          2688.94
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   int64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 77.3+ KB

# %%
df.shape
# Out:
# (1235, 8)

# %%
df.columns.values
# Out:
# array(['Date', 'Open', 'High', 'Low', 'Last', 'Close',
#        'Total Trade Quantity', 'Turnover (Lacs)'], dtype=object)

# %%
df.corr()
# Out:
#                           Open      High  ...  Total Trade Quantity  Turnover (Lacs)
# Open                  1.000000  0.998956  ...              0.367503         0.587026
# High                  0.998956  1.000000  ...              0.388798         0.605907
# Low                   0.998776  0.998728  ...              0.361695         0.582446
# Last                  0.997662  0.999130  ...              0.381269         0.599575
# Close                 0.997704  0.999159  ...              0.380801         0.599155
# Total Trade Quantity  0.367503  0.388798  ...              1.000000         0.941976
# Turnover (Lacs)       0.587026  0.605907  ...              0.941976         1.000000
#
# [7 rows x 7 columns]

# %%
df['Date']= pd.to_datetime(df.Date, format= '%Y-%m-%d')
df.index = df['Date']
df
# Out:
#                  Date    Open  ...  Total Trade Quantity  Turnover (Lacs)
# Date                           ...
# 2018-10-08 2018-10-08  208.00  ...               4642146         10062.83
# 2018-10-05 2018-10-05  217.00  ...               3519515          7407.06
# 2018-10-04 2018-10-04  223.50  ...               1728786          3815.79
# 2018-10-03 2018-10-03  230.00  ...               1708590          3960.27
# 2018-10-01 2018-10-01  234.55  ...               1534749          3486.05
# ...               ...     ...  ...                   ...              ...
# 2013-10-14 2013-10-14  160.85  ...               1281419          2039.09
# 2013-10-11 2013-10-11  161.15  ...               1880046          3030.76
# 2013-10-10 2013-10-10  156.00  ...               3124853          4978.80
# 2013-10-09 2013-10-09  155.70  ...               2049580          3204.49
# 2013-10-08 2013-10-08  157.00  ...               1720413          2688.94
#
# [1235 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(df['Close'],label='CloseHistory')

# %%
data= df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)), columns=['Date','Close'])
new_data
# Out:
#      Date Close
# 0     NaN   NaN
# 1     NaN   NaN
# 2     NaN   NaN
# 3     NaN   NaN
# 4     NaN   NaN
# ...   ...   ...
# 1230  NaN   NaN
# 1231  NaN   NaN
# 1232  NaN   NaN
# 1233  NaN   NaN
# 1234  NaN   NaN
#
# [1235 rows x 2 columns]

# %%
for i in range(0,len(data)):
  new_data['Date'][i]= data['Date'][i]
  new_data['Close'][i]= data['Close'] [i]
new_data
# Out:
#                      Date   Close
# 0     2013-10-08 00:00:00   155.8
# 1     2013-10-09 00:00:00  155.55
# 2     2013-10-10 00:00:00  160.15
# 3     2013-10-11 00:00:00  160.05
# 4     2013-10-14 00:00:00  159.45
# ...                   ...     ...
# 1230  2018-10-01 00:00:00   230.9
# 1231  2018-10-03 00:00:00   227.6
# 1232  2018-10-04 00:00:00   218.2
# 1233  2018-10-05 00:00:00   209.2
# 1234  2018-10-08 00:00:00  215.15
#
# [1235 rows x 2 columns]

# %%
dataset= new_data.values
dataset.shape
# Out:
# (1235, 2)

# %%
from fastai.tabular.all import *

# %%
new_data
# Out:
#                      Date   Close
# 0     2013-10-08 00:00:00   155.8
# 1     2013-10-09 00:00:00  155.55
# 2     2013-10-10 00:00:00  160.15
# 3     2013-10-11 00:00:00  160.05
# 4     2013-10-14 00:00:00  159.45
# ...                   ...     ...
# 1230  2018-10-01 00:00:00   230.9
# 1231  2018-10-03 00:00:00   227.6
# 1232  2018-10-04 00:00:00   218.2
# 1233  2018-10-05 00:00:00   209.2
# 1234  2018-10-08 00:00:00  215.15
#
# [1235 rows x 2 columns]

# %%
add_datepart(new_data, 'Date')
new_data
# Out:
#        Close  Year  Month  ...  Is_year_end  Is_year_start       Elapsed
# 0      155.8  2013     10  ...        False          False  1.381190e+09
# 1     155.55  2013     10  ...        False          False  1.381277e+09
# 2     160.15  2013     10  ...        False          False  1.381363e+09
# 3     160.05  2013     10  ...        False          False  1.381450e+09
# 4     159.45  2013     10  ...        False          False  1.381709e+09
# ...      ...   ...    ...  ...          ...            ...           ...
# 1230   230.9  2018     10  ...        False          False  1.538352e+09
# 1231   227.6  2018     10  ...        False          False  1.538525e+09
# 1232   218.2  2018     10  ...        False          False  1.538611e+09
# 1233   209.2  2018     10  ...        False          False  1.538698e+09
# 1234  215.15  2018     10  ...        False          False  1.538957e+09
#
# [1235 rows x 14 columns]

# %%
new_data.drop('Elapsed', axis=1, inplace=True)

# %%
new_data
# Out:
#        Close  Year  Month  ...  Is_quarter_start  Is_year_end  Is_year_start
# 0      155.8  2013     10  ...             False        False          False
# 1     155.55  2013     10  ...             False        False          False
# 2     160.15  2013     10  ...             False        False          False
# 3     160.05  2013     10  ...             False        False          False
# 4     159.45  2013     10  ...             False        False          False
# ...      ...   ...    ...  ...               ...          ...            ...
# 1230   230.9  2018     10  ...              True        False          False
# 1231   227.6  2018     10  ...             False        False          False
# 1232   218.2  2018     10  ...             False        False          False
# 1233   209.2  2018     10  ...             False        False          False
# 1234  215.15  2018     10  ...             False        False          False
#
# [1235 rows x 13 columns]

# %%
train = new_data[:987]
valid = new_data[987:]

x_train = train.drop('Close', axis=1)
y_train = train['Close']
x_valid = valid.drop('Close', axis=1)
y_valid = valid['Close']

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 10, random_state = 0)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
preds = model.predict(x_valid)
rms=np.sqrt(np.mean(np.power((np.array(y_valid)-np.array(preds)),2)))
rms
# Out:
# 105.5955770371967

# %%
valid
# Out:
#        Close  Year  Month  ...  Is_year_end  Is_year_start  Predictions
# 987    208.3  2017     10  ...        False          False            0
# 988   208.45  2017     10  ...        False          False            0
# 989    209.4  2017     10  ...        False          False            0
# 990      212  2017     10  ...        False          False            0
# 991   210.25  2017     10  ...        False          False            0
# ...      ...   ...    ...  ...          ...            ...          ...
# 1230   230.9  2018     10  ...        False          False            0
# 1231   227.6  2018     10  ...        False          False            0
# 1232   218.2  2018     10  ...        False          False            0
# 1233   209.2  2018     10  ...        False          False            0
# 1234  215.15  2018     10  ...        False          False            0
#
# [248 rows x 14 columns]

# %%
x= valid['Predictions']
x=preds
y= valid['Close']
y=np.array(y)
type(y)
# Out:
# numpy.ndarray

# %%
plt.plot(y)
plt.plot(x)
